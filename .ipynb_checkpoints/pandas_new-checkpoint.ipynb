# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## we have Series and DataFrames in pandas as Datatypes
# ### Series are one dimentional
# ### DataFrames are two dimentional

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=["a",'b','c'],index=['x','y','z'])

# %%
df
# Out:
#    a  b  c
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %% [markdown]
# ### df.head(n) will give us the top n elements of dataframe if n=0 it will give first five
#
# ### df.tail(n) will give the last n elements if n=0 it will give last five elements

# %%
df.head()
# Out:
#    a  b  c
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.head(1)
# Out:
#    a  b  c
# x  1  2  3

# %%
df.tail()
# Out:
#    a  b  c
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.tail(2)
# Out:
#    a  b  c
# y  4  5  6
# z  7  8  9

# %%
df.columns
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df.index
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
type(df.index)
# Out:
# pandas.core.indexes.base.Index

# %%
list(df.index)
# Out:
# ['x', 'y', 'z']

# %% [markdown]
# ## to get the overview of the particular dataframe we have to use df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      int64
#  1   b       3 non-null      int64
#  2   c       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %% [markdown]
# ## If we want to have an overall view of the dataframe i.e mean min,max,std etc...
# #### use df.describe()

# %%
df.describe()
# Out:
#          a    b    c
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()
# Out:
# a    3
# b    3
# c    3
# dtype: int64

# %%
df['a'].unique()
# Out:
# array([1, 4, 7])

# %%
df.a
# Out:
# x    1
# y    4
# z    7
# Name: a, dtype: int64

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ## Loading DataFrames From csv files

# %%
demo=pd.read_csv('/Users/chowdaryadithyasaividivada/Downloads/bios.csv')

# %%
demo
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
demo.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
demo.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
demo.shape
# Out:
# (145500, 10)

# %%
coffee=pd.read_csv('/Users/chowdaryadithyasaividivada/Downloads/coffee.csv')

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.tail()
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %% [markdown]
# ## csv was good format but it will consumes a large amount of data

# %%
coffee.describe()
# Out:
#        Units Sold
# count   14.000000
# mean    32.857143
# std      9.346798
# min     15.000000
# 25%     26.250000
# 50%     35.000000
# 75%     38.750000
# max     45.000000

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes

# %% [markdown]
# ### we use other formats such as feather and parquet to avoid high file sizes

# %%
olympics=pd.read_excel('/Users/chowdaryadithyasaividivada/Downloads/olympics-data.xlsx')

# %%
olympics.head
# Out:
# <bound method NDFrame.head of         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
olympics.shape
# Out:
# (145500, 10)

# %%
olympics_res=pd.read_excel('/Users/chowdaryadithyasaividivada/Downloads/olympics-data.xlsx',sheet_name='results')

# %%
olympics_res
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
olympics_res.shape
# Out:
# (308408, 11)

# %%
results=pd.read_csv('/Users/chowdaryadithyasaividivada/Downloads/results.csv')

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
results['medal'].unique()
# Out:
# array([nan, 'Bronze', 'Silver', 'Gold'], dtype=object)

# %% [markdown]
# # Accessing Data Using Pandas

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
print(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# to get the random data

# %%
coffee.sample(10)
# Out:
#           Day Coffee Type  Units Sold
# 4   Wednesday    Espresso          35
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 2     Tuesday    Espresso          30
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 12     Sunday    Espresso          45
# 10   Saturday    Espresso          45
# 1      Monday       Latte          15
# 0      Monday    Espresso          25

# %%
type(list(coffee.values)[0])
# Out:
# numpy.ndarray

# %% [markdown]
# ## to access the data use df.loc[row,column] function

# %%
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[[0,1,2,3,4]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.loc[0:3]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
coffee.loc[5:]
# Out:
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[:10]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45

# %%
coffee.loc[5:8,['Day','Coffee Type']]
# Out:
#          Day Coffee Type
# 5  Wednesday       Latte
# 6   Thursday    Espresso
# 7   Thursday       Latte
# 8     Friday    Espresso

# %%
coffee.iloc[:,[0,2]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %% [markdown]
# #### if we dont know the column name we can access the data using df.iloc()

# %%
coffee.index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %%
coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
#coffee.index=coffee.Day

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.loc[1,"Units Sold"]=10

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.loc[1:3,"Units Sold"]=10

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# ## to grab a simgle item in the data Frame we can use the df.at[row,col] and df.iat[row,column]

# %%
coffee.at[0,'Units Sold']
# Out:
# 25

# %%
coffee.iat[0,0]
# Out:
# 'Monday'

# %%
coffee.iat[0,1]
# Out:
# 'Espresso'

# %%
coffee.iat[0,2]
# Out:
# 25

# %%
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
type(coffee.loc[0])
# Out:
# pandas.core.series.Series

# %%
for i in range(1,101,1):
    print(i**2)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# 1024
# 1089
# 1156
# 1225
# 1296
# 1369
# 1444
# 1521
# 1600
# 1681
# 1764
# 1849
# 1936
# 2025
# 2116
# 2209
# 2304
# 2401
# 2500
# 2601
# 2704
# 2809
# 2916
# 3025
# 3136
# 3249
# 3364
# 3481
# 3600
# 3721
# 3844
# 3969
# 4096
# 4225
# 4356
# 4489
# 4624
# 4761
# 4900
# 5041
# 5184
# 5329
# 5476
# 5625
# 5776
# 5929
# 6084
# 6241
# 6400
# 6561
# 6724
# 6889
# 7056
# 7225
# 7396
# 7569
# 7744
# 7921
# 8100
# 8281
# 8464
# 8649
# 8836
# 9025
# 9216
# 9409
# 9604
# 9801
# 10000

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          10
# 3    Tuesday       Latte          10
# 4  Wednesday    Espresso          35

# %%
coffee.at[1,'Day']
# Out:
# 'Monday'

# %%
coffee.iloc[:,0]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.loc[:,['Day','Coffee Type']]
# Out:
#           Day Coffee Type
# 0      Monday    Espresso
# 1      Monday       Latte
# 2     Tuesday    Espresso
# 3     Tuesday       Latte
# 4   Wednesday    Espresso
# 5   Wednesday       Latte
# 6    Thursday    Espresso
# 7    Thursday       Latte
# 8      Friday    Espresso
# 9      Friday       Latte
# 10   Saturday    Espresso
# 11   Saturday       Latte
# 12     Sunday    Espresso
# 13     Sunday       Latte

# %%
coffee.loc[coffee['Day']=='Monday']
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso          25
# 1  Monday       Latte          10

# %%
coffee.loc[coffee['Units Sold']>10]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# ## Sorting the Dataframe

# %%
coffee.sort_values(['Units Sold'],ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10

# %%
coffee.sort_values(['Units Sold'],ascending=True)
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
coffee.sort_values(['Coffee Type'])
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          10
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35

# %%
coffee.sort_values(['Day'])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# ## to sort with respect to the two columns  df.sort_values(['Coffee Type','Units Sold'],ascending=[0,1])

# %%
coffee.sort_values(['Coffee Type','Units Sold'],ascending=[1,0])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          10
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 5   Wednesday       Latte          25
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10

# %%
# in the above cell first will be primary second was used during the conflicts

# %% [markdown]
# # Iterate the DataFrame using the Loop

# %%
for index,row in coffee.iterrows():
    print(row)
    print(row['Day'])
    print('\n\n\n')
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
# Monday
#
#
#
#
# Day            Monday
# Coffee Type     Latte
# Units Sold         10
# Name: 1, dtype: object
# Monday
#
#
#
#
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           10
# Name: 2, dtype: object
# Tuesday
#
#
#
#
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          10
# Name: 3, dtype: object
# Tuesday
#
#
#
#
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
# Wednesday
#
#
#
#
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
# Wednesday
#
#
#
#
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
# Thursday
#
#
#
#
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
# Thursday
#
#
#
#
# Day              Friday
# ...

# %% [markdown]
# ## By using the dataframe in the iterator we loose lot of perfomance

# %%
bios=pd.read_csv('/Users/chowdaryadithyasaividivada/Downloads/bios.csv')

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.shape
# Out:
# (145500, 10)

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.columns
# Out:
# Index(['athlete_id', 'name', 'born_date', 'born_city', 'born_region',
#        'born_country', 'NOC', 'height_cm', 'weight_kg', 'died_date'],
#       dtype='object')

# %%
bios.loc[bios['height_cm']>215]['name']
# Out:
# 5089         Viktor Pankrashkin
# 5583       Paulinho Villas Boas
# 5673             Gunther Behnke
# 5716                   Uwe Blab
# 5781             Tommy Burleson
# 5796              Andy Campbell
# 6223                Lars Hansen
# 6270                Hu Zhangbao
# 6409           Sergey Kovalenko
# 6420              Jānis Krūmiņš
# 6504                Luc Longley
# 6722           Shaquille O'Neal
# 6937             David Robinson
# 6978            Arvydas Sabonis
# 7074             Paulo da Silva
# 7188         Vladimir Tkachenko
# 7281           Stojko Vranković
# 7376        Eurelijus Žukauskas
# 52608           Aleksey Kazakov
# 82100             Frédéric Weis
# 89070                  Yao Ming
# 89075            Roberto Dueñas
# 107408         Peter John Ramos
# 112312             Stanko Barać
# 112332      Andreas Glyniadakis
# 112337            Hamed Haddadi
# 118663           Timofey Mozgov
# 118676          Dmitry Musersky
# 120266             Zhang Zhaoxu
# ...

# %%
len(bios.loc[bios['height_cm']>215]['name'])
# Out:
# 35

# %%
type(bios.loc[bios['height_cm']>215]['name'])
# Out:
# pandas.core.series.Series

# %%
bios[bios['height_cm']>215][['name','height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios[(bios['height_cm']>210) & (bios['born_country']=='USA')]
# Out:
#         athlete_id                name   born_date         born_city  \
# 5681          5704        Walt Bellamy  1937-07-24          New Bern
# 5781          5804      Tommy Burleson  1952-02-24         Crossnore
# 5894          5919          Mel Counts  1941-10-16          Coos Bay
# 6106          6133     Marc Freiberger  1928-11-27          Amarillo
# 6281          6309      Darrall Imhoff  1938-10-11       San Gabriel
# 6379          6410          Joe Kleine  1962-01-04  Colorado Springs
# 6393          6424          Jon Koncak  1963-05-17      Cedar Rapids
# 6442          6473  Christian Laettner  1969-08-17            Angola
# 6615          6648        Tom McMillen  1952-05-26         Mansfield
# 6722          6755    Shaquille O'Neal  1972-03-06            Newark
# 6937          6972      David Robinson  1965-08-06          Key West
# 7012          7048     Daniel Santiago  1976-06-24    Tarpon Springs
# 112319      113575         Chris Kaman  1982-04-28           Wyoming
# ...

# %%
len(bios[(bios['height_cm']>210) & (bios['born_country']=='USA')])
# Out:
# 21

# %%
bios.shape
# Out:
# (145500, 10)

# %%
bios.name.str.contains('Mike')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 145495    False
# 145496    False
# 145497    False
# 145498    False
# 145499    False
# Name: name, Length: 145500, dtype: bool

# %%
bios[bios.name.str.contains('Mike')]
# Out:
#         athlete_id             name   born_date      born_city   born_region  \
# 739            743      Mike Bitten  1962-06-02     Senneterre        Québec
# 1235          1242     Mike Strange  1970-08-06  Niagara Falls       Ontario
# 3373          3385     Mike Deveney  1965-12-14      Elderslie      Scotland
# 4195          4209    Mike McCallum  1956-12-07       Kingston      Kingston
# 5652          5675      Mike Bantom  1951-12-03   Philadelphia  Pennsylvania
# ...            ...              ...         ...            ...           ...
# 140301      143807  Mike Rostampour  1991-12-20            NaN           NaN
# 141070      144608       Mike Kawai  1998-06-18            NaN           NaN
# 141957      145543      Mike Foppen  1996-11-29            NaN           NaN
# 142930      146560       Mike Tobey  1994-10-10         Monroe      New York
# 144233      147919      Mike Evelyn  1993-04-13         Ottawa       Ontario
#
# ...

# %%
bios[bios.name.str.contains('Adi|partick')]
# Out:
#         athlete_id                          name   born_date  \
# 5556          5579               Dijiang Adiljan  1967-08-21
# 5940          5966                       Adilson  1951-12-03
# 7578          7619              Adilson da Silva  1967-09-09
# 8526          8573                 Antonio Adipe  1912-04-24
# 9018          9068                     Adi Kainz  1903-06-05
# 9535          9589                Franck Adisson  1969-07-24
# 14594        14692                  Adi Havewala  1917-01-01
# 20128        20271                    Paul Adiga  1952-03-21
# 25722        25915                Adil Khudhayir  1954-07-01
# 26520        26715                  David Adiele  1955-02-05
# 32353        32595                  Adi Popovici  1969-07-01
# 33216        33468                 Adil Bel Gaid  1970-09-15
# 33709        33971                    Adil Kaaba  1971-05-19
# 41522        41840                   Mohsen Adil  1955-06-25
# ...

# %% [markdown]
# ## we can use the regex in the contains method to make it more simple

# %% [markdown]
# ## FIltering Data

# %%
bios[(bios['name'].isin(['Adi']))]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
bios[(bios['born_country'].isin(['USA','FRA','GBR'])) & (bios['name'].str.contains('Adi'))]
# Out:
#         athlete_id            name   born_date  born_city      born_region  \
# 9535          9589  Franck Adisson  1969-07-24     Tarbes  Hautes-Pyrénées
# 120134      121996     Seun Adigun  1987-01-03  Algonquin         Illinois
#
#        born_country      NOC  height_cm  weight_kg died_date
# 9535            FRA   France      180.0       70.0       NaN
# 120134          USA  Nigeria      165.0       70.0       NaN

# %%
bios.query("born_country=='USA'")
# Out:
#         athlete_id               name   born_date         born_city  \
# 54              55      Monique Javer  1967-07-22        Burlingame
# 960            964   Xóchitl Escobedo  1968-09-17       West Covina
# 961            965  Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238     Bert Schneider  1897-07-01         Cleveland
# 1345          1352         Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                ...         ...               ...
# 145445      149168     Kristen Santos  1994-11-02         Fairfield
# 145446      149169   Corinne Stoddard  2001-08-15           Seattle
# 145454      149180      Anna Hoffmann  2000-03-28           Madison
# 145457      149183     Alix Wilkinson  2000-08-02     Mammoth Lakes
# 145468      149195  Justin Abdelkader  1987-02-25          Muskegon
#
#         born_region born_country            NOC  height_cm  weight_kg  \
# 54       California          USA  Great Britain      177.0       64.0
# ...

# %%
coffee['Price']=4.99

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          10   4.99
# 2    Tuesday    Espresso          10   4.99
# 3    Tuesday       Latte          10   4.99
# 4  Wednesday    Espresso          35   4.99

# %%
coffee['newprice']=np.where(coffee['Coffee Type']=='Espresso',3.99,5.99)

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  newprice
# 0     Monday    Espresso          25   4.99      3.99
# 1     Monday       Latte          10   4.99      5.99
# 2    Tuesday    Espresso          10   4.99      3.99
# 3    Tuesday       Latte          10   4.99      5.99
# 4  Wednesday    Espresso          35   4.99      3.99

# %%
coffee.drop(0)
# Out:
#           Day Coffee Type  Units Sold  Price  newprice
# 1      Monday       Latte          10   4.99      5.99
# 2     Tuesday    Espresso          10   4.99      3.99
# 3     Tuesday       Latte          10   4.99      5.99
# 4   Wednesday    Espresso          35   4.99      3.99
# 5   Wednesday       Latte          25   4.99      5.99
# 6    Thursday    Espresso          40   4.99      3.99
# 7    Thursday       Latte          30   4.99      5.99
# 8      Friday    Espresso          45   4.99      3.99
# 9      Friday       Latte          35   4.99      5.99
# 10   Saturday    Espresso          45   4.99      3.99
# 11   Saturday       Latte          35   4.99      5.99
# 12     Sunday    Espresso          45   4.99      3.99
# 13     Sunday       Latte          35   4.99      5.99

# %%
coffee.drop(columns=['Price'],inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  newprice
# 0      Monday    Espresso          25      3.99
# 1      Monday       Latte          10      5.99
# 2     Tuesday    Espresso          10      3.99
# 3     Tuesday       Latte          10      5.99
# 4   Wednesday    Espresso          35      3.99
# 5   Wednesday       Latte          25      5.99
# 6    Thursday    Espresso          40      3.99
# 7    Thursday       Latte          30      5.99
# 8      Friday    Espresso          45      3.99
# 9      Friday       Latte          35      5.99
# 10   Saturday    Espresso          45      3.99
# 11   Saturday       Latte          35      5.99
# 12     Sunday    Espresso          45      3.99
# 13     Sunday       Latte          35      5.99

# %%
coffee_new=coffee
#coffee will be pointing to the same meo=mory

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  newprice
# 0      Monday    Espresso          25      3.99
# 1      Monday       Latte          10      5.99
# 2     Tuesday    Espresso          10      3.99
# 3     Tuesday       Latte          10      5.99
# 4   Wednesday    Espresso          35      3.99
# 5   Wednesday       Latte          25      5.99
# 6    Thursday    Espresso          40      3.99
# 7    Thursday       Latte          30      5.99
# 8      Friday    Espresso          45      3.99
# 9      Friday       Latte          35      5.99
# 10   Saturday    Espresso          45      3.99
# 11   Saturday       Latte          35      5.99
# 12     Sunday    Espresso          45      3.99
# 13     Sunday       Latte          35      5.99

# %%
# to avoid the to use the same memory use the coffee_new=coffee.copy()

# %%
coffee_new=coffee.copy()

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  newprice
# 0      Monday    Espresso          25      3.99
# 1      Monday       Latte          10      5.99
# 2     Tuesday    Espresso          10      3.99
# 3     Tuesday       Latte          10      5.99
# 4   Wednesday    Espresso          35      3.99
# 5   Wednesday       Latte          25      5.99
# 6    Thursday    Espresso          40      3.99
# 7    Thursday       Latte          30      5.99
# 8      Friday    Espresso          45      3.99
# 9      Friday       Latte          35      5.99
# 10   Saturday    Espresso          45      3.99
# 11   Saturday       Latte          35      5.99
# 12     Sunday    Espresso          45      3.99
# 13     Sunday       Latte          35      5.99
