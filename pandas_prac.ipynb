# %%
# %matplotlib inline
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as lpt

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A','B','C'],index=['x','y','z'])

# %%
df
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.head(2)
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6

# %%
df.tail()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.tail(1)
# Out:
#    A  B  C
# z  7  8  9

# %%
df.tail(1)
# Out:
#    A  B  C
# z  7  8  9

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.keys()
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.nunique()
# nunique will give the number of unique values in the data frame with the columns
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['A'].nunique()
# Out:
# 3

# %%
df['A'].unique()
# Out:
# array([1, 4, 7])

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %% [markdown]
# ## Load the Data From the csv

# %%
coffee=pd.read_csv('/Users/chowdaryadithyasaividivada/Downloads/coffee.csv')

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes

# %%
coffee.describe()
# Out:
#        Units Sold
# count   14.000000
# mean    32.857143
# std      9.346798
# min     15.000000
# 25%     26.250000
# 50%     35.000000
# 75%     38.750000
# max     45.000000

# %%
results=pd.read_csv('/Users/chowdaryadithyasaividivada/Downloads/results.csv')

# %%
results
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB

# %%
bios=pd.read_csv('/Users/chowdaryadithyasaividivada/Downloads/bios.csv')

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
olympics=pd.read_excel('/Users/chowdaryadithyasaividivada/Downloads/olympics-data.xlsx')

# %%
olympics
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
print(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
print(olympics)
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
olympics.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
olympics.head(2)
# Out:
#    athlete_id                   name   born_date born_city born_region  \
# 0           1  Jean-François Blanchy  1886-12-12  Bordeaux     Gironde
# 1           2         Arnaud Boetsch  1969-04-01    Meulan    Yvelines
#
#   born_country     NOC  height_cm  weight_kg   died_date
# 0          FRA  France        NaN        NaN  1960-10-02
# 1          FRA  France      183.0       76.0         NaN

# %%
olympics.tail(3)
# Out:
#         athlete_id             name   born_date     born_city  \
# 145497      149224  Yuliya Smirnova  1998-05-08        Kotlas
# 145498      149225   André Foussard  1899-05-19         Niort
# 145499      149814    Bill Phillips  1913-07-15  Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
# to ge the random sample data

# %%
olympics.sample(10)
# Out:
#         athlete_id                     name   born_date     born_city  \
# 100300      101149         Andrei Lyskovets  1974-10-07         Minsk
# 10164        10220          Sayuri Maruyama  1975-12-22           NaN
# 5928          5954              Willy Dasso  1917-01-10          Lima
# 68560        69077             Chris Goudge  1935-03-04     Prestwich
# 142337      145940       Agata Ozdoba-Błach  1988-02-25           NaN
# 137925      141307              Mahdi Habib  1989-03-15           NaN
# 101075      101943           Mariusz Musial  1978-01-01  Jelenia Góra
# 12939        13010      Hans Günter Winkler  1926-07-24           NaN
# 16084        16196            Steve Poulter  1954-12-03      Ormskirk
# 103911      104908  Philaylack Sackpraseuth  1987-04-30           NaN
#
#          born_region born_country                               NOC  \
# 100300         Minsk          BLR                           Belarus
# ...

# %%
olympics.loc[0]
# Out:
# athlete_id                          1
# name            Jean-François Blanchy
# born_date                  1886-12-12
# born_city                    Bordeaux
# born_region                   Gironde
# born_country                      FRA
# NOC                            France
# height_cm                         NaN
# weight_kg                         NaN
# died_date                  1960-10-02
# Name: 0, dtype: object

# %%
olympics.loc[0:5]
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
# 5           6      Nicolas Chatelain  1970-01-13       Amiens
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25
# ...

# %%
olympics.loc[[1,4,3]]
# Out:
#    athlete_id             name   born_date    born_city born_region  \
# 1           2   Arnaud Boetsch  1969-04-01       Meulan    Yvelines
# 4           5     Albert Canet  1878-04-17   Wandsworth     England
# 3           4  Jacques Brugnon  1895-05-11  Paris VIIIe       Paris
#
#   born_country     NOC  height_cm  weight_kg   died_date
# 1          FRA  France      183.0       76.0         NaN
# 4          GBR  France        NaN        NaN  1930-07-25
# 3          FRA  France      168.0       64.0  1978-03-20

# %%
coffee.loc[5:9,['Day','Units Sold']]
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45
# 9     Friday          35

# %%
olympics.loc[olympics['born_country']=='FRA']
# Out:
#         athlete_id                   name   born_date    born_city  \
# 0                1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01       Meulan
# 2                3           Jean Borotra  1898-08-13     Biarritz
# 3                4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                6      Nicolas Chatelain  1970-01-13       Amiens
# ...            ...                    ...         ...          ...
# 144652      148348          James Clugnet  1996-12-04     Grenoble
# 145009      148720        Margaux Hackett  1999-06-02       Annecy
# 145281      149002         Elliott Baralo  1998-08-01       Annecy
# 145467      149194            Elisa Nakab  1998-05-08     Briançon
# 145498      149225         André Foussard  1899-05-19        Niort
#
#                  born_region born_country            NOC  height_cm  \
# 0                    Gironde          FRA         France        NaN
# ...

# %%
olympics.iloc[0:5,0:3]
# Out:
#    athlete_id                   name   born_date
# 0           1  Jean-François Blanchy  1886-12-12
# 1           2         Arnaud Boetsch  1969-04-01
# 2           3           Jean Borotra  1898-08-13
# 3           4        Jacques Brugnon  1895-05-11
# 4           5           Albert Canet  1878-04-17

# %%
olympics.index=olympics['athlete_id']

# %%
olympics.loc[:,['name','born_date']]
# Out:
#                              name   born_date
# athlete_id
# 1           Jean-François Blanchy  1886-12-12
# 2                  Arnaud Boetsch  1969-04-01
# 3                    Jean Borotra  1898-08-13
# 4                 Jacques Brugnon  1895-05-11
# 5                    Albert Canet  1878-04-17
# ...                           ...         ...
# 149222          Polina Luchnikova  2002-01-30
# 149223        Valeriya Merkusheva  1999-09-20
# 149224            Yuliya Smirnova  1998-05-08
# 149225             André Foussard  1899-05-19
# 149814              Bill Phillips  1913-07-15
#
# [145500 rows x 2 columns]

# %%
coffee.loc[1:3,['UnitsSold']]=10

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  UnitsSold
# 0     Monday    Espresso          25        NaN
# 1     Monday       Latte          15       10.0
# 2    Tuesday    Espresso          30       10.0
# 3    Tuesday       Latte          20       10.0
# 4  Wednesday    Espresso          35        NaN

# %%
coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %% [markdown]
# ## Sorting_values

# %%
coffee.sort_values(['Units Sold'])
# Out:
#           Day Coffee Type  Units Sold  UnitsSold
# 1      Monday       Latte          15       10.0
# 3     Tuesday       Latte          20       10.0
# 0      Monday    Espresso          25        NaN
# 5   Wednesday       Latte          25        NaN
# 2     Tuesday    Espresso          30       10.0
# 7    Thursday       Latte          30        NaN
# 4   Wednesday    Espresso          35        NaN
# 9      Friday       Latte          35        NaN
# 11   Saturday       Latte          35        NaN
# 13     Sunday       Latte          35        NaN
# 6    Thursday    Espresso          40        NaN
# 8      Friday    Espresso          45        NaN
# 10   Saturday    Espresso          45        NaN
# 12     Sunday    Espresso          45        NaN

# %%
coffee.sort_values(['Units Sold'],ascending=[0])
# Out:
#           Day Coffee Type  Units Sold  UnitsSold
# 8      Friday    Espresso          45        NaN
# 10   Saturday    Espresso          45        NaN
# 12     Sunday    Espresso          45        NaN
# 6    Thursday    Espresso          40        NaN
# 4   Wednesday    Espresso          35        NaN
# 9      Friday       Latte          35        NaN
# 11   Saturday       Latte          35        NaN
# 13     Sunday       Latte          35        NaN
# 2     Tuesday    Espresso          30       10.0
# 7    Thursday       Latte          30        NaN
# 0      Monday    Espresso          25        NaN
# 5   Wednesday       Latte          25        NaN
# 3     Tuesday       Latte          20       10.0
# 1      Monday       Latte          15       10.0

# %%
coffee.sort_values(['Units Sold','Coffee Type'],ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold  UnitsSold
# 8      Friday    Espresso          45        NaN
# 10   Saturday    Espresso          45        NaN
# 12     Sunday    Espresso          45        NaN
# 6    Thursday    Espresso          40        NaN
# 4   Wednesday    Espresso          35        NaN
# 9      Friday       Latte          35        NaN
# 11   Saturday       Latte          35        NaN
# 13     Sunday       Latte          35        NaN
# 2     Tuesday    Espresso          30       10.0
# 7    Thursday       Latte          30        NaN
# 0      Monday    Espresso          25        NaN
# 5   Wednesday       Latte          25        NaN
# 3     Tuesday       Latte          20       10.0
# 1      Monday       Latte          15       10.0

# %% [markdown]
# ### Iterate over the dataframes with the loop

# %%
for index,row in coffee.iterrows():
    print(index)
    print(row)
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# UnitsSold           NaN
# Name: 0, dtype: object
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# UnitsSold        10.0
# Name: 1, dtype: object
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# UnitsSold          10.0
# Name: 2, dtype: object
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# UnitsSold         10.0
# Name: 3, dtype: object
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# UnitsSold            NaN
# Name: 4, dtype: object
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# UnitsSold            NaN
# Name: 5, dtype: object
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# UnitsSold           NaN
# Name: 6, dtype: object
# 7
# Day            Thursday
# Coffee Type       Latte
# ...

# %%
olympics.loc[1]
# Out:
# athlete_id                          1
# name            Jean-François Blanchy
# born_date                  1886-12-12
# born_city                    Bordeaux
# born_region                   Gironde
# born_country                      FRA
# NOC                            France
# height_cm                         NaN
# weight_kg                         NaN
# died_date                  1960-10-02
# Name: 1, dtype: object

# %%
for (index,row) in coffee.iterrows():
    print(row)
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# UnitsSold           NaN
# Name: 0, dtype: object
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# UnitsSold        10.0
# Name: 1, dtype: object
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# UnitsSold          10.0
# Name: 2, dtype: object
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# UnitsSold         10.0
# Name: 3, dtype: object
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# UnitsSold            NaN
# Name: 4, dtype: object
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# UnitsSold            NaN
# Name: 5, dtype: object
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# UnitsSold           NaN
# Name: 6, dtype: object
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.head(4)
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20

# %%
bios.loc[bios['height_cm']>215]
# Out:
#         athlete_id                   name   born_date               born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5673          5696         Gunther Behnke  1963-01-19              Leverkusen
# 5716          5739               Uwe Blab  1962-03-26        München (Munich)
# 5781          5804         Tommy Burleson  1952-02-24               Crossnore
# 5796          5819          Andy Campbell  1956-07-21               Melbourne
# 6223          6250            Lars Hansen  1954-09-27  København (Copenhagen)
# 6270          6298            Hu Zhangbao  1963-04-05                     NaN
# 6409          6440       Sergey Kovalenko  1947-08-11                     NaN
# 6420          6451          Jānis Krūmiņš  1930-01-30                   Cēsis
# 6504          6537            Luc Longley  1969-01-19               Melbourne
# ...

# %%
bios.loc[bios['height_cm']>215,['name',"height_cm"]]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios[bios['height_cm']>215][['name','height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios.loc[1:5,['name','born_date']]
# Out:
#                 name   born_date
# 1     Arnaud Boetsch  1969-04-01
# 2       Jean Borotra  1898-08-13
# 3    Jacques Brugnon  1895-05-11
# 4       Albert Canet  1878-04-17
# 5  Nicolas Chatelain  1970-01-13

# %%
bios[['name','born_date']]
# Out:
#                          name   born_date
# 0       Jean-François Blanchy  1886-12-12
# 1              Arnaud Boetsch  1969-04-01
# 2                Jean Borotra  1898-08-13
# 3             Jacques Brugnon  1895-05-11
# 4                Albert Canet  1878-04-17
# ...                       ...         ...
# 145495      Polina Luchnikova  2002-01-30
# 145496    Valeriya Merkusheva  1999-09-20
# 145497        Yuliya Smirnova  1998-05-08
# 145498         André Foussard  1899-05-19
# 145499          Bill Phillips  1913-07-15
#
# [145500 rows x 2 columns]

# %%
bios[(bios['height_cm']>215) & (bios['born_country']=='USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
# filtering by string conditions

# %%
bios[(bios['name'].str.contains("Keith",case=False))]
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios['name'].str.contains('Adit',case=False)]
# Out:
#         athlete_id                   name   born_date              born_city  \
# 56416        56818      Prasert Sumpradit  1962-11-22                    NaN
# 73486        74052  John Oladipo Oladitan  1930-11-28                 Ibadan
# 79537        80149     Dimitrios Piaditis         NaN                    NaN
# 101090      101958     Ioannis Leivaditis  1974-01-29                Chicago
# 112947      114234        Tassadit Aïssou  1989-06-19              Sidi-Aïch
# 128047      130551            Aditi Ashok  1998-03-29  Bengaluru (Bangalore)
# 133133      136058        Sarat Sumpradit  1994-04-17           Nakhon Sawan
# 135977      139195         Kaditane Gomis  2002-08-04                    NaN
#
#          born_region born_country       NOC  height_cm  weight_kg   died_date
# 56416            NaN          NaN  Thailand      173.0       75.0         NaN
# 73486            Oyo          NGR   Nigeria      180.0       76.0  2002-06-17
# ...

# %%
bios[bios['name'].str.contains('adi|keith',case=False)]
# Out:
#         athlete_id                  name   born_date  \
# 210            211          Ilona Váradi  1891-08-04
# 260            261             Suharyadi  1965-02-14
# 281            282            S. M. Hadi  1899-08-12
# 368            369       Sylvain Cadieux  1974-09-25
# 604            606         Nadia Bisiach  1965-01-25
# ...            ...                   ...         ...
# 144863      148568     Vladislav Kireyev  2000-09-24
# 144877      148582     Adil Galiakhmetov  1998-11-16
# 145463      149190     Vladimir Tkachyov  1993-10-05
# 145474      149201     Nadine Hofstetter  1994-10-21
# 145481      149208  Vladislav Zharovtsev  1996-05-01
#
#                         born_city       born_region born_country          NOC  \
# 210                      Budapest          Budapest          HUN      Hungary
# 260                         Blora       Jawa Tengah          INA    Indonesia
# 281                     Hyderabad    Andhra Pradesh          IND        India
# ...

# %%
bios[bios['name'].str.contains('adi|keith',case=False,regex=False)]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
bios[(bios['born_country'].isin(['USA','FRA','GBR']))&(bios['name'].str.contains('Adi',case=False))]
# Out:
#         athlete_id                       name   born_date  \
# 9535          9589             Franck Adisson  1969-07-24
# 13204        13284                René Abadie  1935-08-13
# 15318        15423                Marc Madiot  1959-04-16
# 17743        17864            Vladimir Aïtoff  1879-08-05
# 20696        20843           Nadia Boudesoque  1918-04-11
# 24881        25070              Sadi Dastarac  1888-06-14
# 28189        28399               Nadia Mimoun  1978-12-28
# 29643        29868              Raymond Badin  1928-03-19
# 36752        37046          Bernard Meynadier  1938-04-19
# 41762        42082              Franck Badiou  1967-03-24
# 46364        46711             Nadine Delache  1941-02-07
# 46523        46871           Vladimir Latocha  1973-08-15
# 50746        51105             Helene Madison  1913-06-19
# 55247        55642              Ernest Cadine  1893-07-12
# 67385        67896  Nadine Auzeil-Schoellkopf  1964-08-19
# ...

# %%
bios[(bios['name'].str.startswith('keith'))]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %% [markdown]
# # Query functions

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  UnitsSold
# 0      Monday    Espresso          25        NaN
# 1      Monday       Latte          15       10.0
# 2     Tuesday    Espresso          30       10.0
# 3     Tuesday       Latte          20       10.0
# 4   Wednesday    Espresso          35        NaN
# 5   Wednesday       Latte          25        NaN
# 6    Thursday    Espresso          40        NaN
# 7    Thursday       Latte          30        NaN
# 8      Friday    Espresso          45        NaN
# 9      Friday       Latte          35        NaN
# 10   Saturday    Espresso          45        NaN
# 11   Saturday       Latte          35        NaN
# 12     Sunday    Espresso          45        NaN
# 13     Sunday       Latte          35        NaN

# %%
coffee.sort_values(['Units Sold','Day'],ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold  UnitsSold
# 8      Friday    Espresso          45        NaN
# 10   Saturday    Espresso          45        NaN
# 12     Sunday    Espresso          45        NaN
# 6    Thursday    Espresso          40        NaN
# 9      Friday       Latte          35        NaN
# 11   Saturday       Latte          35        NaN
# 13     Sunday       Latte          35        NaN
# 4   Wednesday    Espresso          35        NaN
# 7    Thursday       Latte          30        NaN
# 2     Tuesday    Espresso          30       10.0
# 0      Monday    Espresso          25        NaN
# 5   Wednesday       Latte          25        NaN
# 3     Tuesday       Latte          20       10.0
# 1      Monday       Latte          15       10.0

# %% [markdown]
# ## Query Functions

# %%
bios.query('born_country=="USA" and born_city=="Seattle"')
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
bios.head(3)
# Out:
#    athlete_id                   name   born_date born_city  \
# 0           1  Jean-François Blanchy  1886-12-12  Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01    Meulan
# 2           3           Jean Borotra  1898-08-13  Biarritz
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
#  3   UnitsSold    3 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 580.0+ bytes

# %% [markdown]
# ## Adding and Removing the elements

# %%
coffee['price']=4.00

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
#  3   UnitsSold    3 non-null      float64
#  4   price        14 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 692.0+ bytes

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  UnitsSold  price
# 0      Monday    Espresso          25        NaN    4.0
# 1      Monday       Latte          15       10.0    4.0
# 2     Tuesday    Espresso          30       10.0    4.0
# 3     Tuesday       Latte          20       10.0    4.0
# 4   Wednesday    Espresso          35        NaN    4.0
# 5   Wednesday       Latte          25        NaN    4.0
# 6    Thursday    Espresso          40        NaN    4.0
# 7    Thursday       Latte          30        NaN    4.0
# 8      Friday    Espresso          45        NaN    4.0
# 9      Friday       Latte          35        NaN    4.0
# 10   Saturday    Espresso          45        NaN    4.0
# 11   Saturday       Latte          35        NaN    4.0
# 12     Sunday    Espresso          45        NaN    4.0
# 13     Sunday       Latte          35        NaN    4.0

# %%
coffee['newprice']=np.where(coffee['Coffee Type']=='Espresso',3.99,4.99)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  UnitsSold  price  newprice
# 0      Monday    Espresso          25        NaN    4.0      3.99
# 1      Monday       Latte          15       10.0    4.0      4.99
# 2     Tuesday    Espresso          30       10.0    4.0      3.99
# 3     Tuesday       Latte          20       10.0    4.0      4.99
# 4   Wednesday    Espresso          35        NaN    4.0      3.99
# 5   Wednesday       Latte          25        NaN    4.0      4.99
# 6    Thursday    Espresso          40        NaN    4.0      3.99
# 7    Thursday       Latte          30        NaN    4.0      4.99
# 8      Friday    Espresso          45        NaN    4.0      3.99
# 9      Friday       Latte          35        NaN    4.0      4.99
# 10   Saturday    Espresso          45        NaN    4.0      3.99
# 11   Saturday       Latte          35        NaN    4.0      4.99
# 12     Sunday    Espresso          45        NaN    4.0      3.99
# ...

# %%
coffee.drop(columns=['price'])
# Out:
#           Day Coffee Type  Units Sold  UnitsSold  newprice
# 0      Monday    Espresso          25        NaN      3.99
# 1      Monday       Latte          15       10.0      4.99
# 2     Tuesday    Espresso          30       10.0      3.99
# 3     Tuesday       Latte          20       10.0      4.99
# 4   Wednesday    Espresso          35        NaN      3.99
# 5   Wednesday       Latte          25        NaN      4.99
# 6    Thursday    Espresso          40        NaN      3.99
# 7    Thursday       Latte          30        NaN      4.99
# 8      Friday    Espresso          45        NaN      3.99
# 9      Friday       Latte          35        NaN      4.99
# 10   Saturday    Espresso          45        NaN      3.99
# 11   Saturday       Latte          35        NaN      4.99
# 12     Sunday    Espresso          45        NaN      3.99
# 13     Sunday       Latte          35        NaN      4.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  UnitsSold  price  newprice
# 0      Monday    Espresso          25        NaN    4.0      3.99
# 1      Monday       Latte          15       10.0    4.0      4.99
# 2     Tuesday    Espresso          30       10.0    4.0      3.99
# 3     Tuesday       Latte          20       10.0    4.0      4.99
# 4   Wednesday    Espresso          35        NaN    4.0      3.99
# 5   Wednesday       Latte          25        NaN    4.0      4.99
# 6    Thursday    Espresso          40        NaN    4.0      3.99
# 7    Thursday       Latte          30        NaN    4.0      4.99
# 8      Friday    Espresso          45        NaN    4.0      3.99
# 9      Friday       Latte          35        NaN    4.0      4.99
# 10   Saturday    Espresso          45        NaN    4.0      3.99
# 11   Saturday       Latte          35        NaN    4.0      4.99
# 12     Sunday    Espresso          45        NaN    4.0      3.99
# ...

# %%
coffee.drop(columns=['price'],inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  UnitsSold  newprice
# 0      Monday    Espresso          25        NaN      3.99
# 1      Monday       Latte          15       10.0      4.99
# 2     Tuesday    Espresso          30       10.0      3.99
# 3     Tuesday       Latte          20       10.0      4.99
# 4   Wednesday    Espresso          35        NaN      3.99
# 5   Wednesday       Latte          25        NaN      4.99
# 6    Thursday    Espresso          40        NaN      3.99
# 7    Thursday       Latte          30        NaN      4.99
# 8      Friday    Espresso          45        NaN      3.99
# 9      Friday       Latte          35        NaN      4.99
# 10   Saturday    Espresso          45        NaN      3.99
# 11   Saturday       Latte          35        NaN      4.99
# 12     Sunday    Espresso          45        NaN      3.99
# 13     Sunday       Latte          35        NaN      4.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  UnitsSold  newprice
# 0      Monday    Espresso          25        NaN      3.99
# 1      Monday       Latte          15       10.0      4.99
# 2     Tuesday    Espresso          30       10.0      3.99
# 3     Tuesday       Latte          20       10.0      4.99
# 4   Wednesday    Espresso          35        NaN      3.99
# 5   Wednesday       Latte          25        NaN      4.99
# 6    Thursday    Espresso          40        NaN      3.99
# 7    Thursday       Latte          30        NaN      4.99
# 8      Friday    Espresso          45        NaN      3.99
# 9      Friday       Latte          35        NaN      4.99
# 10   Saturday    Espresso          45        NaN      3.99
# 11   Saturday       Latte          35        NaN      4.99
# 12     Sunday    Espresso          45        NaN      3.99
# 13     Sunday       Latte          35        NaN      4.99

# %%
coffee[['Day','Coffee Type','Units Sold','newprice']]
# Out:
#           Day Coffee Type  Units Sold  newprice
# 0      Monday    Espresso          25      3.99
# 1      Monday       Latte          15      4.99
# 2     Tuesday    Espresso          30      3.99
# 3     Tuesday       Latte          20      4.99
# 4   Wednesday    Espresso          35      3.99
# 5   Wednesday       Latte          25      4.99
# 6    Thursday    Espresso          40      3.99
# 7    Thursday       Latte          30      4.99
# 8      Friday    Espresso          45      3.99
# 9      Friday       Latte          35      4.99
# 10   Saturday    Espresso          45      3.99
# 11   Saturday       Latte          35      4.99
# 12     Sunday    Espresso          45      3.99
# 13     Sunday       Latte          35      4.99

# %%
coffee['revenue']=coffee['Units Sold']*coffee['newprice']

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  UnitsSold  newprice  revenue
# 0      Monday    Espresso          25        NaN      3.99    99.75
# 1      Monday       Latte          15       10.0      4.99    74.85
# 2     Tuesday    Espresso          30       10.0      3.99   119.70
# 3     Tuesday       Latte          20       10.0      4.99    99.80
# 4   Wednesday    Espresso          35        NaN      3.99   139.65
# 5   Wednesday       Latte          25        NaN      4.99   124.75
# 6    Thursday    Espresso          40        NaN      3.99   159.60
# 7    Thursday       Latte          30        NaN      4.99   149.70
# 8      Friday    Espresso          45        NaN      3.99   179.55
# 9      Friday       Latte          35        NaN      4.99   174.65
# 10   Saturday    Espresso          45        NaN      3.99   179.55
# 11   Saturday       Latte          35        NaN      4.99   174.65
# 12     Sunday    Espresso          45        NaN      3.99   179.55
# ...

# %%
coffee.rename(columns={'newprice':'price'},inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  UnitsSold  price  revenue
# 0      Monday    Espresso          25        NaN   3.99    99.75
# 1      Monday       Latte          15       10.0   4.99    74.85
# 2     Tuesday    Espresso          30       10.0   3.99   119.70
# 3     Tuesday       Latte          20       10.0   4.99    99.80
# 4   Wednesday    Espresso          35        NaN   3.99   139.65
# 5   Wednesday       Latte          25        NaN   4.99   124.75
# 6    Thursday    Espresso          40        NaN   3.99   159.60
# 7    Thursday       Latte          30        NaN   4.99   149.70
# 8      Friday    Espresso          45        NaN   3.99   179.55
# 9      Friday       Latte          35        NaN   4.99   174.65
# 10   Saturday    Espresso          45        NaN   3.99   179.55
# 11   Saturday       Latte          35        NaN   4.99   174.65
# 12     Sunday    Espresso          45        NaN   3.99   179.55
# ...

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios['name']
# Out:
# 0         Jean-François Blanchy
# 1                Arnaud Boetsch
# 2                  Jean Borotra
# 3               Jacques Brugnon
# 4                  Albert Canet
#                   ...
# 145495        Polina Luchnikova
# 145496      Valeriya Merkusheva
# 145497          Yuliya Smirnova
# 145498           André Foussard
# 145499            Bill Phillips
# Name: name, Length: 145500, dtype: object

# %%
bios['name']=bios['name'].str.split(" ").str[0]

# %%
bios['name']
# Out:
# 0         Jean-François
# 1                Arnaud
# 2                  Jean
# 3               Jacques
# 4                Albert
#               ...
# 145495           Polina
# 145496         Valeriya
# 145497           Yuliya
# 145498            André
# 145499             Bill
# Name: name, Length: 145500, dtype: object

# %%
name=bios.query('name=="Keith"))
# Out:
#   Cell In[126], line 1
#     name=bios.query('name=="Keith"))
#                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
name
# Out:
#         athlete_id   name   born_date     born_city       born_region  \
# 1897          1907  Keith  1966-09-01           NaN               NaN
# 3505          3517  Keith  1961-03-29       Preston           England
# 6228          6255  Keith  1940-10-15     Vancouver  British Columbia
# 8898          8946  Keith  1966-01-01           NaN               NaN
# 12053        12118  Keith  1898-11-03        Fulham           England
# ...            ...    ...         ...           ...               ...
# 99921       100722  Keith  1970-02-03    Providence      Rhode Island
# 102227      103168  Keith  1983-02-09        London           Ontario
# 109900      111105  Keith  1927-08-25  Christchurch        Canterbury
# 115973      117348  Keith  1975-02-02      Plymouth     Massachusetts
# 122121      124176  Keith  1979-09-07          Sale          Victoria
#
#        born_country            NOC  height_cm  weight_kg   died_date
# ...
