# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Default DataFrames

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]])

# %%
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# the above is the custom dataframen with out any columns and indexes

# %%
df1=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A','B','C'],index=['x','y','z'])

# %%
df1
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
# basic properties

# %%
df1.shape
# Out:
# (3, 3)

# %%
df1.ndim
# Out:
# 2

# %%
df1.size
# Out:
# 9

# %%
# to print the top 5 elements

# %%
df1.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df1.head(1)
# Out:
#    A  B  C
# x  1  2  3

# %%
df1.tail()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df1.tail(1)
# Out:
#    A  B  C
# z  7  8  9

# %%
# to retrive the columns of the dataframe

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
# convert to the list
list(df1.columns)
# Out:
# ['A', 'B', 'C']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes

# %%
df1.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
# to print all the unique elements in an data froma

df1.nunique()
# nunique gives us the number if n=unique elements in an elements
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df1.A.unique()
# Out:
# array([1, 4, 7])

# %%
df1.B.unique()
# Out:
# array([2, 5, 8])

# %%
for i in list(df1.columns):
    print(df1[i].unique)
    print()
# Out:
# <bound method Series.unique of x    1
# y    4
# z    7
# Name: A, dtype: int64>
#
# <bound method Series.unique of x    2
# y    5
# z    8
# Name: B, dtype: int64>
#
# <bound method Series.unique of x    3
# y    6
# z    9
# Name: C, dtype: int64>

# %% [markdown]
# ## Loading of the DataFrames from external files

# %%
coffee=pd.read_csv('/Users/chowdaryadithyasaividivada/Downloads/coffee.csv')

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# different formats of the loading of the data is

# %%
#results=pd.read_parquet('/Users/chowdaryadithyasaividivada/Downloads/results.parquet')
#this not run without dependency

# %%
bios=pd.read_csv('/Users/chowdaryadithyasaividivada/Downloads/bios.csv')

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.shape
# Out:
# (145500, 10)

# %%
bios.ndim
# Out:
# 2

# %%
bios.size
# Out:
# 1455000

# %%
olympicsdata=pd.read_excel('/Users/chowdaryadithyasaividivada/Downloads/olympics-data.xlsx')

# %%
olympicsdata
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
olympicsdata.shape
# Out:
# (145500, 10)

# %%
olympicsdata.ndim
olympicsdata.size
# Out:
# 1455000

# %%
print(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# to print we us print(coffee)  to print as an table we use the display option

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.tail()
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.sample(6)
# Out:
#           Day Coffee Type  Units Sold
# 12     Sunday    Espresso          45
# 4   Wednesday    Espresso          35
# 8      Friday    Espresso          45
# 6    Thursday    Espresso          40
# 11   Saturday       Latte          35
# 7    Thursday       Latte          30

# %%
# coffee.sample(n) will return the n random rows form the data frame

# %% [markdown]
# ## Retriving of the data

# %%
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
# the above give the nth row

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# play around with the rows and columns

# %%
coffee.loc[[0,5,2]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 5  Wednesday       Latte          25
# 2    Tuesday    Espresso          30

# %%
coffee.loc[4:12,['Day']]
# Out:
#           Day
# 4   Wednesday
# 5   Wednesday
# 6    Thursday
# 7    Thursday
# 8      Friday
# 9      Friday
# 10   Saturday
# 11   Saturday
# 12     Sunday

# %%
# we can select the columsn as shown above

# %%
coffee.loc[0:5,['Day','Coffee Type','Units Sold']]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25

# %%
# retriving through the numeric indexes rather than assigned

# %%
coffee.iloc[3:10,[i for i in range(3)]]
# Out:
#          Day Coffee Type  Units Sold
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35

# %%
coffee.index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %%
print(coffee.index)
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %%
coffee.index=coffee.Day

# %%
display(coffee)
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25
# Thursday    Thursday    Espresso          40
# Thursday    Thursday       Latte          30
# Friday        Friday    Espresso          45
# Friday        Friday       Latte          35
# Saturday    Saturday    Espresso          45
# Saturday    Saturday       Latte          35
# Sunday        Sunday    Espresso          45
# Sunday        Sunday       Latte          35

# %%
coffee.loc['Wednesday']
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25

# %%
coffee.loc['Monday':'Wednesday']
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25

# %%
coffee.loc['Monday':'Wednesday',['units']]=10

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold  units
# Day
# Monday        Monday    Espresso          25   10.0
# Monday        Monday       Latte          15   10.0
# Tuesday      Tuesday    Espresso          30   10.0
# Tuesday      Tuesday       Latte          20   10.0
# Wednesday  Wednesday    Espresso          35   10.0
# Wednesday  Wednesday       Latte          25   10.0
# Thursday    Thursday    Espresso          40    NaN
# Thursday    Thursday       Latte          30    NaN
# Friday        Friday    Espresso          45    NaN
# Friday        Friday       Latte          35    NaN
# Saturday    Saturday    Espresso          45    NaN
# Saturday    Saturday       Latte          35    NaN
# Sunday        Sunday    Espresso          45    NaN
# Sunday        Sunday       Latte          35    NaN

# %%
coffee.Day
# Out:
# Day
# Monday          Monday
# Monday          Monday
# Tuesday        Tuesday
# Tuesday        Tuesday
# Wednesday    Wednesday
# Wednesday    Wednesday
# Thursday      Thursday
# Thursday      Thursday
# Friday          Friday
# Friday          Friday
# Saturday      Saturday
# Saturday      Saturday
# Sunday          Sunday
# Sunday          Sunday
# Name: Day, dtype: object

# %%
# to position the elements

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold  units
# Day
# Monday        Monday    Espresso          25   10.0
# Monday        Monday       Latte          15   10.0
# Tuesday      Tuesday    Espresso          30   10.0
# Tuesday      Tuesday       Latte          20   10.0
# Wednesday  Wednesday    Espresso          35   10.0
# Wednesday  Wednesday       Latte          25   10.0
# Thursday    Thursday    Espresso          40    NaN
# Thursday    Thursday       Latte          30    NaN
# Friday        Friday    Espresso          45    NaN
# Friday        Friday       Latte          35    NaN
# Saturday    Saturday    Espresso          45    NaN
# Saturday    Saturday       Latte          35    NaN
# Sunday        Sunday    Espresso          45    NaN
# Sunday        Sunday       Latte          35    NaN

# %%
coffee.iat[3,1]
# Out:
# 'Latte'

# %%
coffee.at['Monday','Units Sold']
# Out:
# Day
# Monday    25
# Monday    15
# Name: Units Sold, dtype: int64

# %% [markdown]
# ## To sort the values

# %%
for i in list(coffee.columns):
    print(coffee[i].unique)
    print()
# Out:
# <bound method Series.unique of Day
# Monday          Monday
# Monday          Monday
# Tuesday        Tuesday
# Tuesday        Tuesday
# Wednesday    Wednesday
# Wednesday    Wednesday
# Thursday      Thursday
# Thursday      Thursday
# Friday          Friday
# Friday          Friday
# Saturday      Saturday
# Saturday      Saturday
# Sunday          Sunday
# Sunday          Sunday
# Name: Day, dtype: object>
#
# <bound method Series.unique of Day
# Monday       Espresso
# Monday          Latte
# Tuesday      Espresso
# Tuesday         Latte
# Wednesday    Espresso
# Wednesday       Latte
# Thursday     Espresso
# Thursday        Latte
# Friday       Espresso
# Friday          Latte
# Saturday     Espresso
# Saturday        Latte
# Sunday       Espresso
# Sunday          Latte
# Name: Coffee Type, dtype: object>
#
# <bound method Series.unique of Day
# Monday       25
# Monday       15
# Tuesday      30
# Tuesday      20
# Wednesday    35
# Wednesday    25
# Thursday     40
# ...

# %%
coffee.sort_values(['Units Sold'])
# Out:
#                  Day Coffee Type  Units Sold  units
# Day
# Monday        Monday       Latte          15   10.0
# Tuesday      Tuesday       Latte          20   10.0
# Monday        Monday    Espresso          25   10.0
# Wednesday  Wednesday       Latte          25   10.0
# Tuesday      Tuesday    Espresso          30   10.0
# Thursday    Thursday       Latte          30    NaN
# Wednesday  Wednesday    Espresso          35   10.0
# Friday        Friday       Latte          35    NaN
# Saturday    Saturday       Latte          35    NaN
# Sunday        Sunday       Latte          35    NaN
# Thursday    Thursday    Espresso          40    NaN
# Friday        Friday    Espresso          45    NaN
# Saturday    Saturday    Espresso          45    NaN
# Sunday        Sunday    Espresso          45    NaN

# %%
coffee.sort_index()
# Out:
#                  Day Coffee Type  Units Sold  units
# Day
# Friday        Friday    Espresso          45    NaN
# Friday        Friday       Latte          35    NaN
# Monday        Monday    Espresso          25   10.0
# Monday        Monday       Latte          15   10.0
# Saturday    Saturday    Espresso          45    NaN
# Saturday    Saturday       Latte          35    NaN
# Sunday        Sunday    Espresso          45    NaN
# Sunday        Sunday       Latte          35    NaN
# Thursday    Thursday    Espresso          40    NaN
# Thursday    Thursday       Latte          30    NaN
# Tuesday      Tuesday    Espresso          30   10.0
# Tuesday      Tuesday       Latte          20   10.0
# Wednesday  Wednesday    Espresso          35   10.0
# Wednesday  Wednesday       Latte          25   10.0

# %%
coffee.sort_index(ascending=False)
# with respect to the length
# Out:
#                  Day Coffee Type  Units Sold  units
# Day
# Wednesday  Wednesday    Espresso          35   10.0
# Wednesday  Wednesday       Latte          25   10.0
# Tuesday      Tuesday    Espresso          30   10.0
# Tuesday      Tuesday       Latte          20   10.0
# Thursday    Thursday    Espresso          40    NaN
# Thursday    Thursday       Latte          30    NaN
# Sunday        Sunday    Espresso          45    NaN
# Sunday        Sunday       Latte          35    NaN
# Saturday    Saturday    Espresso          45    NaN
# Saturday    Saturday       Latte          35    NaN
# Monday        Monday    Espresso          25   10.0
# Monday        Monday       Latte          15   10.0
# Friday        Friday    Espresso          45    NaN
# Friday        Friday       Latte          35    NaN

# %%
coffee.sort_values(['Units Sold','Coffee Type'],ascending=[0,1])
# Out:
#                  Day Coffee Type  Units Sold  units
# Day
# Friday        Friday    Espresso          45    NaN
# Saturday    Saturday    Espresso          45    NaN
# Sunday        Sunday    Espresso          45    NaN
# Thursday    Thursday    Espresso          40    NaN
# Wednesday  Wednesday    Espresso          35   10.0
# Friday        Friday       Latte          35    NaN
# Saturday    Saturday       Latte          35    NaN
# Sunday        Sunday       Latte          35    NaN
# Tuesday      Tuesday    Espresso          30   10.0
# Thursday    Thursday       Latte          30    NaN
# Monday        Monday    Espresso          25   10.0
# Wednesday  Wednesday       Latte          25   10.0
# Tuesday      Tuesday       Latte          20   10.0
# Monday        Monday       Latte          15   10.0

# %%
# iterate over the dataframe

# %%
for i in range(coffee.shape[0]):
    print(coffee.iloc[i])
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# units              10.0
# Name: Monday, dtype: object
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# units            10.0
# Name: Monday, dtype: object
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# units              10.0
# Name: Tuesday, dtype: object
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# units             10.0
# Name: Tuesday, dtype: object
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# units               10.0
# Name: Wednesday, dtype: object
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# units               10.0
# Name: Wednesday, dtype: object
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# units               NaN
# Name: Thursday, dtype: object
# Day            Thursday
# Coffee Type       Latte
# ...

# %%
coffee.tail(2)
# Out:
#            Day Coffee Type  Units Sold  units
# Day
# Sunday  Sunday    Espresso          45    NaN
# Sunday  Sunday       Latte          35    NaN

# %%
# second method

# %%
for i,row in coffee.iterrows():
    print(i)
    print(row)
# Out:
# Monday
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# units              10.0
# Name: Monday, dtype: object
# Monday
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# units            10.0
# Name: Monday, dtype: object
# Tuesday
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# units              10.0
# Name: Tuesday, dtype: object
# Tuesday
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# units             10.0
# Name: Tuesday, dtype: object
# Wednesday
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# units               10.0
# Name: Wednesday, dtype: object
# Wednesday
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# units               10.0
# Name: Wednesday, dtype: object
# Thursday
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# units               NaN
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.loc[0]
# Out:
# athlete_id                          1
# name            Jean-François Blanchy
# born_date                  1886-12-12
# born_city                    Bordeaux
# born_region                   Gironde
# born_country                      FRA
# NOC                            France
# height_cm                         NaN
# weight_kg                         NaN
# died_date                  1960-10-02
# Name: 0, dtype: object

# %%
bios['height_cm']>165
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4         False
#           ...
# 145495     True
# 145496     True
# 145497    False
# 145498     True
# 145499    False
# Name: height_cm, Length: 145500, dtype: bool

# %%
bios[bios['height_cm']>200]
# Out:
#         athlete_id                name   born_date         born_city  \
# 1080          1087      Bozhil Lozanov  1934-08-16               NaN
# 1673          1680    Alexis Rubalcaba  1972-08-09  Pedro Betancourt
# 2647          2659       Milan Šrejber  1963-12-30    Praha (Prague)
# 2827          2839  Nik'oloz Deriugini  1959-04-30           Kutaisi
# 2832          2844       Elşad Qadaşev  1968-05-01              Bakı
# ...            ...                 ...         ...               ...
# 143784      147440  Daniel Miklasevich  1997-07-17               NaN
# 143833      147489  Garrett Muagututia  1988-02-26               NaN
# 143834      147490         Kyle Ensing  1997-03-06               NaN
# 143835      147491         Mitch Stahl  1994-08-31               NaN
# 143919      147577   Emerson Rodríguez  1993-02-02           Caracas
#
#                born_region born_country             NOC  height_cm  weight_kg  \
# ...

# %%
bios.loc[bios['height_cm']>165]
# Out:
#         athlete_id                 name   born_date        born_city  \
# 1                2       Arnaud Boetsch  1969-04-01           Meulan
# 2                3         Jean Borotra  1898-08-13         Biarritz
# 3                4      Jacques Brugnon  1895-05-11      Paris VIIIe
# 5                6    Nicolas Chatelain  1970-01-13           Amiens
# 6                7        Patrick Chila  1969-11-27      Ris-Orangis
# ...            ...                  ...         ...              ...
# 145473      149200       Toms Andersons  1993-11-25             Rīga
# 145494      149221        George Wright  1890-07-21          Toronto
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145498      149225       André Foussard  1899-05-19            Niort
#
#                  born_region born_country     NOC  height_cm  weight_kg  \
# ...

# %%
bios.loc[bios['height_cm']>164,['name','born_date']]
# Out:
#                        name   born_date
# 1            Arnaud Boetsch  1969-04-01
# 2              Jean Borotra  1898-08-13
# 3           Jacques Brugnon  1895-05-11
# 5         Nicolas Chatelain  1970-01-13
# 6             Patrick Chila  1969-11-27
# ...                     ...         ...
# 145473       Toms Andersons  1993-11-25
# 145494        George Wright  1890-07-21
# 145495    Polina Luchnikova  2002-01-30
# 145496  Valeriya Merkusheva  1999-09-20
# 145498       André Foussard  1899-05-19
#
# [93622 rows x 2 columns]

# %%
# bios.loc method was used to select the columns to be displayed

# %%
bios[(bios['height_cm']>215 )& (bios['born_country']=='USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %% [markdown]
# ## Filtering out the conditions using string matching

# %%
bios[bios['name'].str.contains('keith',case=False)]
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios['name'].str.contains('Adi',case=False)]
# Out:
#         athlete_id                  name   born_date  \
# 210            211          Ilona Váradi  1891-08-04
# 260            261             Suharyadi  1965-02-14
# 281            282            S. M. Hadi  1899-08-12
# 368            369       Sylvain Cadieux  1974-09-25
# 604            606         Nadia Bisiach  1965-01-25
# ...            ...                   ...         ...
# 144863      148568     Vladislav Kireyev  2000-09-24
# 144877      148582     Adil Galiakhmetov  1998-11-16
# 145463      149190     Vladimir Tkachyov  1993-10-05
# 145474      149201     Nadine Hofstetter  1994-10-21
# 145481      149208  Vladislav Zharovtsev  1996-05-01
#
#                         born_city       born_region born_country          NOC  \
# 210                      Budapest          Budapest          HUN      Hungary
# 260                         Blora       Jawa Tengah          INA    Indonesia
# 281                     Hyderabad    Andhra Pradesh          IND        India
# ...

# %%
bios.sort_values(['name'],ascending=False)
# Out:
#         athlete_id               name   born_date       born_city  \
# 99727       100526    Аlex Halcheniuk  1967-07-28           Minsk
# 80057        80708  Ștefania Botcariu  1936-01-11        Bistrița
# 32372        32615      Ștefan Zoller  1914-08-27           Sibiu
# 104214      105226      Ștefan Vasile  1982-02-17          Brăila
# 104603      105625   Ștefan Vasilache  1979-05-09           Roman
# ...            ...                ...         ...             ...
# 23976        24163         Abel Braga  1952-09-01  Rio de Janeiro
# 113784      115084       Abdul Rashid  1979-02-15        Khanewal
# 19821        19960       Abdul Rashid  1922-06-01      Rawalpindi
# 73853        74423       Abdul Rashid  1928-04-25             NaN
# 19822        19961       Abdul Rashid  1947-03-03           Bannu
#
#                born_region born_country       NOC  height_cm  weight_kg  \
# 99727                Minsk          BLR   Belarus      181.0       87.0
# ...

# %%
# more funcions

# %%
bios.loc[bios['name'].str.contains('adi|keith',case=False),['name','born_date']]
# Out:
#                         name   born_date
# 210             Ilona Váradi  1891-08-04
# 260                Suharyadi  1965-02-14
# 281               S. M. Hadi  1899-08-12
# 368          Sylvain Cadieux  1974-09-25
# 604            Nadia Bisiach  1965-01-25
# ...                      ...         ...
# 144863     Vladislav Kireyev  2000-09-24
# 144877     Adil Galiakhmetov  1998-11-16
# 145463     Vladimir Tkachyov  1993-10-05
# 145474     Nadine Hofstetter  1994-10-21
# 145481  Vladislav Zharovtsev  1996-05-01
#
# [1309 rows x 2 columns]

# %%
# we can use the regex in the pandas.str.contains() method

# %%
bios.loc[(bios['born_country'].isin(['USA','FRA','GBR'])) & (bios['name'].str.contains('adi',case=False))]
# Out:
#         athlete_id                       name   born_date  \
# 9535          9589             Franck Adisson  1969-07-24
# 13204        13284                René Abadie  1935-08-13
# 15318        15423                Marc Madiot  1959-04-16
# 17743        17864            Vladimir Aïtoff  1879-08-05
# 20696        20843           Nadia Boudesoque  1918-04-11
# 24881        25070              Sadi Dastarac  1888-06-14
# 28189        28399               Nadia Mimoun  1978-12-28
# 29643        29868              Raymond Badin  1928-03-19
# 36752        37046          Bernard Meynadier  1938-04-19
# 41762        42082              Franck Badiou  1967-03-24
# 46364        46711             Nadine Delache  1941-02-07
# 46523        46871           Vladimir Latocha  1973-08-15
# 50746        51105             Helene Madison  1913-06-19
# 55247        55642              Ernest Cadine  1893-07-12
# 67385        67896  Nadine Auzeil-Schoellkopf  1964-08-19
# ...

# %% [markdown]
# ## Query Functions

# %%
bios.query("born_country=='USA' and born_city=='Seattle'")
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
# ...

# %%
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold  units
# Day
# Monday        Monday    Espresso          25   10.0
# Monday        Monday       Latte          15   10.0
# Tuesday      Tuesday    Espresso          30   10.0
# Tuesday      Tuesday       Latte          20   10.0
# Wednesday  Wednesday    Espresso          35   10.0

# %%
coffee.head(10)
# Out:
#                  Day Coffee Type  Units Sold  units
# Day
# Monday        Monday    Espresso          25   10.0
# Monday        Monday       Latte          15   10.0
# Tuesday      Tuesday    Espresso          30   10.0
# Tuesday      Tuesday       Latte          20   10.0
# Wednesday  Wednesday    Espresso          35   10.0
# Wednesday  Wednesday       Latte          25   10.0
# Thursday    Thursday    Espresso          40    NaN
# Thursday    Thursday       Latte          30    NaN
# Friday        Friday    Espresso          45    NaN
# Friday        Friday       Latte          35    NaN

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold  units
# Day
# Monday        Monday    Espresso          25   10.0
# Monday        Monday       Latte          15   10.0
# Tuesday      Tuesday    Espresso          30   10.0
# Tuesday      Tuesday       Latte          20   10.0
# Wednesday  Wednesday    Espresso          35   10.0
# Wednesday  Wednesday       Latte          25   10.0
# Thursday    Thursday    Espresso          40    NaN
# Thursday    Thursday       Latte          30    NaN
# Friday        Friday    Espresso          45    NaN
# Friday        Friday       Latte          35    NaN
# Saturday    Saturday    Espresso          45    NaN
# Saturday    Saturday       Latte          35    NaN
# Sunday        Sunday    Espresso          45    NaN
# Sunday        Sunday       Latte          35    NaN

# %% [markdown]
# ### Adding the new column

# %%
coffee['price']=5.99

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold  units  price
# Day
# Monday        Monday    Espresso          25   10.0   5.99
# Monday        Monday       Latte          15   10.0   5.99
# Tuesday      Tuesday    Espresso          30   10.0   5.99
# Tuesday      Tuesday       Latte          20   10.0   5.99
# Wednesday  Wednesday    Espresso          35   10.0   5.99
# Wednesday  Wednesday       Latte          25   10.0   5.99
# Thursday    Thursday    Espresso          40    NaN   5.99
# Thursday    Thursday       Latte          30    NaN   5.99
# Friday        Friday    Espresso          45    NaN   5.99
# Friday        Friday       Latte          35    NaN   5.99
# Saturday    Saturday    Espresso          45    NaN   5.99
# Saturday    Saturday       Latte          35    NaN   5.99
# Sunday        Sunday    Espresso          45    NaN   5.99
# Sunday        Sunday       Latte          35    NaN   5.99

# %%
coffee['price']
# Out:
# Day
# Monday       5.99
# Monday       5.99
# Tuesday      5.99
# Tuesday      5.99
# Wednesday    5.99
# Wednesday    5.99
# Thursday     5.99
# Thursday     5.99
# Friday       5.99
# Friday       5.99
# Saturday     5.99
# Saturday     5.99
# Sunday       5.99
# Sunday       5.99
# Name: price, dtype: float64

# %%
type(coffee['price'])
# Out:
# pandas.core.series.Series

# %%
## to modify the dataframes in different form

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold  units  price
# Day
# Monday        Monday    Espresso          25   10.0   5.99
# Monday        Monday       Latte          15   10.0   5.99
# Tuesday      Tuesday    Espresso          30   10.0   5.99
# Tuesday      Tuesday       Latte          20   10.0   5.99
# Wednesday  Wednesday    Espresso          35   10.0   5.99
# Wednesday  Wednesday       Latte          25   10.0   5.99
# Thursday    Thursday    Espresso          40    NaN   5.99
# Thursday    Thursday       Latte          30    NaN   5.99
# Friday        Friday    Espresso          45    NaN   5.99
# Friday        Friday       Latte          35    NaN   5.99
# Saturday    Saturday    Espresso          45    NaN   5.99
# Saturday    Saturday       Latte          35    NaN   5.99
# Sunday        Sunday    Espresso          45    NaN   5.99
# Sunday        Sunday       Latte          35    NaN   5.99

# %%
coffee['new price']=np.where(coffee['Coffee Type']=='Espresso',3.99,5.99)

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold  units  price  new price
# Day
# Monday        Monday    Espresso          25   10.0   5.99       3.99
# Monday        Monday       Latte          15   10.0   5.99       5.99
# Tuesday      Tuesday    Espresso          30   10.0   5.99       3.99
# Tuesday      Tuesday       Latte          20   10.0   5.99       5.99
# Wednesday  Wednesday    Espresso          35   10.0   5.99       3.99
# Wednesday  Wednesday       Latte          25   10.0   5.99       5.99
# Thursday    Thursday    Espresso          40    NaN   5.99       3.99
# Thursday    Thursday       Latte          30    NaN   5.99       5.99
# Friday        Friday    Espresso          45    NaN   5.99       3.99
# Friday        Friday       Latte          35    NaN   5.99       5.99
# Saturday    Saturday    Espresso          45    NaN   5.99       3.99
# Saturday    Saturday       Latte          35    NaN   5.99       5.99
# ...

# %%
coffee.drop(columns=['new price'],inplace=True)

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold  units  price
# Day
# Monday        Monday    Espresso          25   10.0   5.99
# Monday        Monday       Latte          15   10.0   5.99
# Tuesday      Tuesday    Espresso          30   10.0   5.99
# Tuesday      Tuesday       Latte          20   10.0   5.99
# Wednesday  Wednesday    Espresso          35   10.0   5.99
# Wednesday  Wednesday       Latte          25   10.0   5.99
# Thursday    Thursday    Espresso          40    NaN   5.99
# Thursday    Thursday       Latte          30    NaN   5.99
# Friday        Friday    Espresso          45    NaN   5.99
# Friday        Friday       Latte          35    NaN   5.99
# Saturday    Saturday    Espresso          45    NaN   5.99
# Saturday    Saturday       Latte          35    NaN   5.99
# Sunday        Sunday    Espresso          45    NaN   5.99
# Sunday        Sunday       Latte          35    NaN   5.99

# %%
coffee['revenue']=coffee['price']*coffee['Units Sold']

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold  units  price  revenue
# Day
# Monday        Monday    Espresso          25   10.0   5.99   149.75
# Monday        Monday       Latte          15   10.0   5.99    89.85
# Tuesday      Tuesday    Espresso          30   10.0   5.99   179.70
# Tuesday      Tuesday       Latte          20   10.0   5.99   119.80
# Wednesday  Wednesday    Espresso          35   10.0   5.99   209.65
# Wednesday  Wednesday       Latte          25   10.0   5.99   149.75
# Thursday    Thursday    Espresso          40    NaN   5.99   239.60
# Thursday    Thursday       Latte          30    NaN   5.99   179.70
# Friday        Friday    Espresso          45    NaN   5.99   269.55
# Friday        Friday       Latte          35    NaN   5.99   209.65
# Saturday    Saturday    Espresso          45    NaN   5.99   269.55
# Saturday    Saturday       Latte          35    NaN   5.99   209.65
# Sunday        Sunday    Espresso          45    NaN   5.99   269.55
# ...

# %%
coffee.rename(columns={'price':'newprice'})
# Out:
#                  Day Coffee Type  Units Sold  units  newprice  revenue
# Day
# Monday        Monday    Espresso          25   10.0      5.99   149.75
# Monday        Monday       Latte          15   10.0      5.99    89.85
# Tuesday      Tuesday    Espresso          30   10.0      5.99   179.70
# Tuesday      Tuesday       Latte          20   10.0      5.99   119.80
# Wednesday  Wednesday    Espresso          35   10.0      5.99   209.65
# Wednesday  Wednesday       Latte          25   10.0      5.99   149.75
# Thursday    Thursday    Espresso          40    NaN      5.99   239.60
# Thursday    Thursday       Latte          30    NaN      5.99   179.70
# Friday        Friday    Espresso          45    NaN      5.99   269.55
# Friday        Friday       Latte          35    NaN      5.99   209.65
# Saturday    Saturday    Espresso          45    NaN      5.99   269.55
# Saturday    Saturday       Latte          35    NaN      5.99   209.65
# ...

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios['firstname']=(bios['name'].str.split(' ').str[0])

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.query("firstname=='Keith'")
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# ...

# %%
bios.to_csv('/Users/chowdaryadithyasaividivada/Documents/Pandas/bioscsv.csv')
